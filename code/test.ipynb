# %%
import pandas as pd
import ray
from ray.rllib.algorithms.ppo import PPOConfig
from ray import tune
import gym
from gym import spaces
import numpy as np

# %%
# Load the AAPL order book CSV
file_path = "/Users/mrunalmania/Machine Learning Projects & Books/Projects/BlockHouse Assignment/Blockhouse-Work-Trial/data/AAPL_Quotes_Data.csv"  # Replace with your actual file path
order_book = pd.read_csv(file_path)

# %%
import ray
from ray.rllib.algorithms.ppo import PPOConfig
from ray.tune.registry import register_env
import gym
from gym import spaces
import numpy as np
import pandas as pd  # Ensure pandas is imported for DataFrame handling



# Define the custom AAPL Trading environment
class AAPLTradingEnv(gym.Env):
    def __init__(self, order_book, V=10000, H=100, I=10, T=10):
        super(AAPLTradingEnv, self).__init__()
        self.order_book = order_book
        self.V = V  # Total volume to trade
        self.H = H  # Time horizon
        self.I = I  # Number of inventory divisions
        self.T = T  # Number of time divisions

        # Observation space now contains top 5 bid and ask prices, along with time and remaining inventory
        self.observation_space = spaces.Box(
            low=0, high=1, 
            shape=(10 + 1,),  # 10 prices + time + inventory
            dtype=np.float32
        )
        
        # Action space (Hold, Cross Spread, Place in Own Book)
        self.action_space = spaces.Discrete(3)

        self.reset()

    def reset(self):
        self.current_step = 0
        self.remaining_volume = self.V
        self.state = self._get_observation()
        return self.state

    def _get_observation(self):
        """Returns normalized observation including top 5 bid and ask prices"""
        row = self.order_book.iloc[self.current_step]
        bid_prices = row[['bid_price_1', 'bid_price_2', 'bid_price_3', 'bid_price_4', 'bid_price_5']].values
        ask_prices = row[['ask_price_1', 'ask_price_2', 'ask_price_3', 'ask_price_4', 'ask_price_5']].values

        normalized_time = self.current_step / self.T
        normalized_inventory = self.remaining_volume / self.V

        # Concatenate prices with normalized time and inventory
        obs = np.concatenate([bid_prices, ask_prices, [normalized_time, normalized_inventory]])
        return obs

    def step(self, action):
        # Retrieve current bid and ask prices
        row = self.order_book.iloc[self.current_step]
        ask_price = row['ask_price_1']
        bid_price = row['bid_price_1']

        reward = 0
        done = False

        # Simulate the action effects
        if action == 0:  # Hold
            reward = 0
        elif action == 1:  # Cross the spread
            reward = -(ask_price - bid_price) * self.remaining_volume / self.V
            self.remaining_volume = 0  # All shares sold
        elif action == 2:  # Place in own book (wait for market takers)
            if np.random.random() < 0.5:  # Random fill condition
                reward = (ask_price - bid_price) * (self.remaining_volume / 2) / self.V
                self.remaining_volume /= 2

        # Update step and check if done
        self.current_step += 1
        if self.current_step >= self.T or self.remaining_volume <= 0:
            done = True
        
        return self._get_observation(), reward, done, {}

# Initialize Ray
ray.shutdown()
ray.init()

# Register the custom environment
def env_creator(env_config):
    return AAPLTradingEnv(order_book=env_config["order_book"], V=env_config["V"], H=env_config["H"], I=env_config["I"], T=env_config["T"])

register_env("aapl_trading_env", env_creator)

# PPO configuration for Ray 2.x
config = (
    PPOConfig()
    .environment("aapl_trading_env", env_config={"order_book": order_book, "V": 10000, "H": 100, "I": 10, "T": 10})
    .framework("torch")  # We will use PyTorch for this
    .training(lr=1e-4, train_batch_size=1000)
    .resources(num_gpus=0)  # Adjust if using GPUs
    .rollouts(num_rollout_workers=1)  # Single worker for simplicity
)

# Add model configuration
config = config.training(model={"fcnet_hiddens": [128, 128], "fcnet_activation": "relu"})

# Create PPO trainer instance
algo = config.build()

# Training loop
for i in range(10):  # Run multiple training iterations
    result = algo.train()
    print(f"Iteration: {i}, Reward: {result['episode_reward_mean']}")

# Save the trained model
checkpoint = algo.save()
print(f"Checkpoint saved at: {checkpoint}")

# Shutdown Ray
ray.shutdown()
# Out:
# 2024-10-24 14:21:07,900	INFO worker.py:1816 -- Started a local Ray instance.
# 2024-10-24 14:21:08,356	WARNING deprecation.py:50 -- DeprecationWarning: `AlgorithmConfig.env_runners(num_rollout_workers)` has been deprecated. Use `AlgorithmConfig.env_runners(num_env_runners)` instead. This will raise an error in the future!
# 2024-10-24 14:21:10,116	ERROR actor_manager.py:804 -- Ray error (The actor died because of an error raised in its creation task, ray::RolloutWorker.__init__() (pid=79624, ip=127.0.0.1, actor_id=d5983fd4653357746b424ce301000000, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x169a784a0>)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ray/rllib/evaluation/rollout_worker.py", line 467, in __init__
#     self.policy_dict, self.is_policy_to_train = self.config.get_multi_agent_setup(
#                                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ray/rllib/algorithms/algorithm_config.py", line 5014, in get_multi_agent_setup
#     raise ValueError(
# ValueError: `observation_space` not provided in PolicySpec for default_policy and env does not have an observation space OR no spaces received from other workers' env(s) OR no `observation_space` specified in config!), taking actor 1 out of service.
# ---------------------------------------------------------------------------
# ActorDiedError                            Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ray/rllib/env/env_runner_group.py:194, in EnvRunnerGroup.__init__(self, env_creator, validate_env, default_policy_class, config, num_env_runners, local_env_runner, logdir, _setup, tune_trial_id, num_workers, local_worker)
#     193 try:
# --> 194     self._setup(
#     195         validate_env=validate_env,
#     196         config=config,
#     197         num_env_runners=num_env_runners,
#     198         local_env_runner=local_env_runner,
#     199     )
#     200 # EnvRunnerGroup creation possibly fails, if some (remote) workers cannot
#     201 # be initialized properly (due to some errors in the EnvRunners's
#     202 # constructor).
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ray/rllib/env/env_runner_group.py:264, in EnvRunnerGroup._setup(self, validate_env, config, num_env_runners, local_env_runner)
#     263 # Create a number of @ray.remote workers.
# --> 264 self.add_workers(
#     265     num_env_runners,
#     266     validate=config.validate_env_runners_after_construction,
#     267 )
#     269 # If num_env_runners > 0 and we don't have an env on the local worker,
#     270 # get the observation- and action spaces for each policy from
#     271 # the first remote worker (which does have an env).
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ray/rllib/env/env_runner_group.py:801, in EnvRunnerGroup.add_workers(self, num_workers, validate)
#     800 else:
# --> 801     raise e
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ray/rllib/utils/actor_manager.py:792, in FaultTolerantActorManager._fetch_result(self, remote_actor_ids, remote_calls, tags, timeout_seconds, return_obj_refs, mark_healthy)
#     791 try:
# --> 792     result = ray.get(ready)
#     794 # Any error type other than `RayError` happening during ray.get() ->
#     795 # Throw exception right here (we don't know how to handle these non-remote
#     796 # worker issues and should therefore crash).
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ray/_private/auto_init_hook.py:21, in wrap_auto_init.<locals>.auto_init_wrapper(*args, **kwargs)
#      20 auto_init_ray()
# ---> 21 return fn(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ray/_private/client_mode_hook.py:103, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     102         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 103 return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ray/_private/worker.py:2745, in get(object_refs, timeout)
#    2744 # TODO(ujvl): Consider how to allow user to retrieve the ready objects.
# -> 2745 values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#    2746 for i, value in enumerate(values):
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ray/_private/worker.py:903, in Worker.get_objects(self, object_refs, timeout, return_exceptions)
#     902             else:
# --> 903                 raise value
#     905 return values, debugger_breakpoint
#
# ActorDiedError: The actor died because of an error raised in its creation task, ray::RolloutWorker.__init__() (pid=79624, ip=127.0.0.1, actor_id=d5983fd4653357746b424ce301000000, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x169a784a0>)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ray/rllib/evaluation/rollout_worker.py", line 467, in __init__
#     self.policy_dict, self.is_policy_to_train = self.config.get_multi_agent_setup(
#                                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ray/rllib/algorithms/algorithm_config.py", line 5014, in get_multi_agent_setup
#     raise ValueError(
# ValueError: `observation_space` not provided in PolicySpec for default_policy and env does not have an observation space OR no spaces received from other workers' env(s) OR no `observation_space` specified in config!
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 104
#     101 config = config.training(model={"fcnet_hiddens": [128, 128], "fcnet_activation": "relu"})
#     103 # Create PPO trainer instance
# --> 104 algo = config.build()
#     106 # Training loop
#     107 for i in range(10):  # Run multiple training iterations
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ray/rllib/algorithms/algorithm_config.py:952, in AlgorithmConfig.build(self, env, logger_creator, use_copy)
#     949 if isinstance(self.algo_class, str):
#     950     algo_class = get_trainable_cls(self.algo_class)
# --> 952 return algo_class(
#     953     config=self if not use_copy else copy.deepcopy(self),
#     954     logger_creator=self.logger_creator,
#     955 )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ray/rllib/algorithms/algorithm.py:584, in Algorithm.__init__(self, config, env, logger_creator, **kwargs)
#     581 # Evaluation EnvRunnerGroup and metrics last returned by `self.evaluate()`.
#     582 self.eval_env_runner_group: Optional[EnvRunnerGroup] = None
# --> 584 super().__init__(
#     585     config=config,
#     586     logger_creator=logger_creator,
#     587     **kwargs,
#     588 )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ray/tune/trainable/trainable.py:158, in Trainable.__init__(self, config, logger_creator, storage)
#     154     logger.debug(f"StorageContext on the TRAINABLE:\n{storage}")
#     156 self._open_logfiles(stdout_file, stderr_file)
# --> 158 self.setup(copy.deepcopy(self.config))
#     159 setup_time = time.time() - self._start_time
#     160 if setup_time > SETUP_TIME_THRESHOLD:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ray/rllib/algorithms/algorithm.py:670, in Algorithm.setup(self, config)
#     667     self.config.off_policy_estimation_methods = ope_dict
#     669 # Create a set of env runner actors via a EnvRunnerGroup.
# --> 670 self.env_runner_group = EnvRunnerGroup(
#     671     env_creator=self.env_creator,
#     672     validate_env=self.validate_env,
#     673     default_policy_class=self.get_default_policy_class(self.config),
#     674     config=self.config,
#     675     num_env_runners=(
#     676         0
#     677         if (
#     678             self.config.input_
#     679             and (
#     680                 isinstance(self.config.input_, str)
#     681                 or (
#     682                     isinstance(self.config.input_, list)
#     683                     and isinstance(self.config.input_[0], str)
#     684                 )
#     685             )
#     686             and self.config.input_ != "sampler"
#     687             and self.config.enable_rl_module_and_learner
#     688         )
#     689         else self.config.num_env_runners
#     690     ),
#     691     local_env_runner=True,
#     692     logdir=self.logdir,
#     693     tune_trial_id=self.trial_id,
#     694 )
#     696 # If an input path is available and we are on the new API stack generate
#     697 # an `OfflineData` instance.
#     698 if (
#     699     self.config.input_
#     700     and (
#    (...)
#     708     and self.config.enable_rl_module_and_learner
#     709 ):
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ray/rllib/env/env_runner_group.py:216, in EnvRunnerGroup.__init__(self, env_creator, validate_env, default_policy_class, config, num_env_runners, local_env_runner, logdir, _setup, tune_trial_id, num_workers, local_worker)
#     203 except RayActorError as e:
#     204     # In case of an actor (remote worker) init failure, the remote worker
#     205     # may still exist and will be accessible, however, e.g. calling
#     206     # its `sample.remote()` would result in strange "property not found"
#     207     # errors.
#     208     if e.actor_init_failed:
#     209         # Raise the original error here that the EnvRunners raised
#     210         # during its construction process. This is to enforce transparency
#    (...)
#     214         # - e.args[0].args[2]: The original Exception (e.g. a ValueError due
#     215         # to a config mismatch) thrown inside the actor.
# --> 216         raise e.args[0].args[2]
#     217     # In any other case, raise the RayActorError as-is.
#     218     else:
#     219         raise e
#
# ValueError: `observation_space` not provided in PolicySpec for default_policy and env does not have an observation space OR no spaces received from other workers' env(s) OR no `observation_space` specified in config!
# (RolloutWorker pid=79624) Exception raised in creation task: The actor died because of an error raised in its creation task, ray::RolloutWorker.__init__() (pid=79624, ip=127.0.0.1, actor_id=d5983fd4653357746b424ce301000000, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x169a784a0>)
# (RolloutWorker pid=79624)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=79624)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=79624)   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ray/rllib/evaluation/rollout_worker.py", line 467, in __init__
# (RolloutWorker pid=79624)     self.policy_dict, self.is_policy_to_train = self.config.get_multi_agent_setup(
# (RolloutWorker pid=79624)                                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=79624)   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ray/rllib/algorithms/algorithm_config.py", line 5014, in get_multi_agent_setup
# (RolloutWorker pid=79624)     raise ValueError(
# (RolloutWorker pid=79624) ValueError: `observation_space` not provided in PolicySpec for default_policy and env does not have an observation space OR no spaces received from other workers' env(s) OR no `observation_space` specified in config!
